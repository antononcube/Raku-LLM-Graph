# %% [markdown]
# # LLM graph iteration demo
#
# <p style="font-size: 20px; font-weight: bold; font-style: italic;">...without LLM</p>
#
# Anton Antonov
# January 2026

# %% [markdown]
# ---
#
# ## Introduction

# %% [markdown]
# This notebook shows how to do iterative refinements of results agent results using a iterative evaluation of an (acyclic) LLM-graph.
# The setup uses a deterministic, "toy LLM" that allows for quick and easy demonstration of the overall process. (And it is suitable for debugging.)

# %% [markdown]
# ---
#
# ## Setup

# %%
use LLM::Graph;

# %% [markdown]
# ---
#
# ## Define state and a tiny deterministic LLM stub
#
# The stub makes the output repeatable so you can focus on graph behavior.

# %%
proto sub toy-llm($form) {*}

multi sub toy-llm(Str:D $draft) {
    toy-llm({critique => '', critique-iteration => 0, revision => $draft, revision-iteration => 0})
}

multi sub toy-llm(%form) {
    if %form<critique-iteration> ≤ %form<revision-iteration> {
        %form<critique> = do given %form<critique-iteration> {
            when $_ == 0  { 'Needs a clearer thesis and one concrete example.' }
            when $_ == 1  { 'Much better. Add a concise closing sentence.' }
            default { "Looks good." }
        }
        %form<critique-iteration> += 1;
        return %form
    }
    %form<revision> ~= "\n[Revision applied: tightened and clarified.]";
    %form<revision-iteration> += 1;
    return %form
}
# Out:
# &toy-llm

# %% [markdown]
# ----
#
# ## Graph nodes
#
# The cycle is: generate -> critique -> revise -> critique -> ... and stops when the critique says "Looks good." or max iterations is reached.

# %%
sink my %generation-rules =

    generate => { 
        eval-function => sub ($topic) {
            my $draft = "Draft (iteration 1) on $topic:\n" ~
            "- Thesis: $topic matters.\n" ~ 
            "- Point: Provide one benefit.\n" ~
            "- Example: TBD.\n";
            return $draft;
        }
    }
;

# %%
sink my %revision-rules =

    decide => { 
        eval-function => sub ($text) { 
            !(
                $text ~~ Str:D && $text.contains("Looks good") ||
                $text ~~ Map:D && $text<critique>.contains("Looks good")
            )
        } 
    },

    critique => {
        eval-function => sub ($text) {
            return toy-llm($text) if $text ~~ Str:D;
            
            my $form = $text.clone; 
            $form<critique-iteration> += $form<critique-iteration>;

            return toy-llm($form);
        },
        
        test-function => sub ($decide) { $decide.raku.lc.contains('true') }
    },

    revise => {
        eval-function => sub ($text, $critique) {
            my $form = $critique.clone;
            $form = toy-llm($form);
            return $form;
        },
        
        test-function => sub ($critique) { $critique.defined }
    },

    finalize => {
        eval-function => sub ($text, $revise) { $revise.defined ?? $revise !! $text}
    }  
;

# %% [markdown]
# ---
#
#
# ## Build the graphs

# %%
my $g1 = LLM::Graph.new(%generation-rules):!async;
my $g2 = LLM::Graph.new(%revision-rules):!async;

(:$g1, :$g2)
# Out:
# (g1 => LLM::Graph(size => 1, nodes => generate) g2 => LLM::Graph(size => 4, nodes => critique, decide, finalize, revise))

# %% [markdown]
# ---
#
# ## Run and inspect state transitions

# %%
$g1.eval({ topic => "why cyclic graphs help with iterative writing" })
# Out:
# LLM::Graph(size => 1, nodes => generate)

# %%
my $text = $g1.nodes<generate><result>
# Out:
# Draft (iteration 1) on why cyclic graphs help with iterative writing:
# - Thesis: why cyclic graphs help with iterative writing matters.
# - Point: Provide one benefit.
# - Example: TBD.

# %%
$g2.eval({ :$text })
# Out:
# LLM::Graph(size => 4, nodes => critique, decide, finalize, revise)

# %%
$g2.nodes<revise>
# Out:
# {eval-function => sub { }, input => [critique text], result => {critique => Needs a clearer thesis and one concrete example., critique-iteration => 1, revision => Draft (iteration 1) on why cyclic graphs help with iterative writing:
# - Thesis: why cyclic graphs help with iterative writing matters.
# - Point: Provide one benefit.
# - Example: TBD.
#
# [Revision applied: tightened and clarified.], revision-iteration => 1}, spec-type => (Callable), test-function => sub { }, test-function-input => [critique], test-function-result => True}

# %%
$g1.clear;
$g2.clear;

$g1.eval({ topic => "why cyclic graphs helpe with iterative writin??g" });
my $text = $g1.nodes<generate><result>;

for (^4) -> $iter {
  say '-' x 10, $iter, '-' x 10;
  $g2.eval({:$text});  
  my $revision = $g2.nodes<finalize><result>;
  last if $revision eq $text;
  $text = $revision
}

$text
# Out:
# ----------0----------
# ----------1----------
# ----------2----------
# {critique => Looks good., critique-iteration => 3, revision => Draft (iteration 1) on why cyclic graphs helpe with iterative writin??g:
# - Thesis: why cyclic graphs helpe with iterative writin??g matters.
# - Point: Provide one benefit.
# - Example: TBD.
#
# [Revision applied: tightened and clarified.]
# [Revision applied: tightened and clarified.], revision-iteration => 2}

# %% [markdown]
# ----
#
# ## Final output

# %%
#% html
my %opts = engine => 'dot', :9graph-size, node-width => 1.2, theme => 'ortho';
[
    generation-graph => $g1.dot(|%opts, :1graph-size, :svg),
    revision-graph => $g2.dot(|%opts, :3graph-size, :svg)
]
==> to-html-table()
# Out:
# <table style="border-collapse: collapse; border: 3px solid black;"><thead><tr><th style="border: 3px solid black; text-align: left;">generation-graph</th><th style="border: 3px solid black; text-align: left;">revision-graph</th></tr></thead><tbody><tr><td style="border: 3px solid black; text-align: left;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (20251213.1925)
#  -->
# <!-- Pages: 1 -->
# <svg width="72pt" height="64pt"
#  viewBox="0.00 0.00 72.00 64.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.73789 0.73789) rotate(0) translate(4 83.2)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-83.2 93.58,-83.2 93.58,4 -4,4"/>
# <!-- generate -->
# <g id="node1" class="node">
# <title>generate</title>
# <polygon fill="SteelBlue" stroke="Grey" points="87.99,-21.6 1.59,-21.6 1.59,0 87.99,0 87.99,-21.6"/>
# <text xml:space="preserve" text-anchor="middle" x="44.79" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">generate</text>
# </g>
# <!-- topic -->
# <g id="node2" class="node">
# <title>topic</title>
# <polygon fill="SteelBlue" stroke="Grey" points="89.58,-79.2 18.33,-79.2 0,-57.6 71.25,-57.6 89.58,-79.2"/>
# <text xml:space="preserve" text-anchor="middle" x="44.79" y="-64.12" font-family="Times,serif" font-size="12.00" fill="White">topic</text>
# </g>
# <!-- topic&#45;&gt;generate -->
# <g id="edge1" class="edge">
# <title>topic&#45;&gt;generate</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M44.79,-57.29C44.79,-57.29 44.79,-33.08 44.79,-33.08"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="48.29,-33.08 44.79,-23.08 41.29,-33.08 48.29,-33.08"/>
# </g>
# </g>
# </svg>
# </td><td style="border: 3px solid black; text-align: left;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (20251213.1925)
#  -->
# <!-- Pages: 1 -->
# <svg width="139pt" height="216pt"
#  viewBox="0.00 0.00 139.00 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.830769 0.830769) rotate(0) translate(4 256)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-256 163.4,-256 163.4,4 -4,4"/>
# <!-- critique -->
# <g id="node1" class="node">
# <title>critique</title>
# <polygon fill="SteelBlue" stroke="Grey" points="86.4,-136.8 0,-136.8 0,-115.2 86.4,-115.2 86.4,-136.8"/>
# <text xml:space="preserve" text-anchor="middle" x="43.2" y="-121.72" font-family="Times,serif" font-size="12.00" fill="White">critique</text>
# </g>
# <!-- revise -->
# <g id="node4" class="node">
# <title>revise</title>
# <polygon fill="SteelBlue" stroke="Grey" points="124.4,-79.2 38,-79.2 38,-57.6 124.4,-57.6 124.4,-79.2"/>
# <text xml:space="preserve" text-anchor="middle" x="81.2" y="-64.12" font-family="Times,serif" font-size="12.00" fill="White">revise</text>
# </g>
# <!-- critique&#45;&gt;revise -->
# <g id="edge6" class="edge">
# <title>critique&#45;&gt;revise</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M62.2,-114.89C62.2,-114.89 62.2,-90.68 62.2,-90.68"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="65.7,-90.68 62.2,-80.68 58.7,-90.68 65.7,-90.68"/>
# </g>
# <!-- decide -->
# <g id="node2" class="node">
# <title>decide</title>
# <polygon fill="SteelBlue" stroke="Grey" points="86.4,-194.4 0,-194.4 0,-172.8 86.4,-172.8 86.4,-194.4"/>
# <text xml:space="preserve" text-anchor="middle" x="43.2" y="-179.32" font-family="Times,serif" font-size="12.00" fill="White">decide</text>
# </g>
# <!-- decide&#45;&gt;critique -->
# <g id="edge7" class="edge">
# <title>decide&#45;&gt;critique</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" stroke-dasharray="5,2" d="M43.2,-172.49C43.2,-172.49 43.2,-148.28 43.2,-148.28"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="46.7,-148.28 43.2,-138.28 39.7,-148.28 46.7,-148.28"/>
# </g>
# <!-- finalize -->
# <g id="node3" class="node">
# <title>finalize</title>
# <polygon fill="SteelBlue" stroke="Grey" points="159.4,-21.6 73,-21.6 73,0 159.4,0 159.4,-21.6"/>
# <text xml:space="preserve" text-anchor="middle" x="116.2" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">finalize</text>
# </g>
# <!-- revise&#45;&gt;finalize -->
# <g id="edge1" class="edge">
# <title>revise&#45;&gt;finalize</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M98.7,-57.29C98.7,-57.29 98.7,-33.08 98.7,-33.08"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="102.2,-33.08 98.7,-23.08 95.2,-33.08 102.2,-33.08"/>
# </g>
# <!-- text -->
# <g id="node5" class="node">
# <title>text</title>
# <polygon fill="SteelBlue" stroke="Grey" points="122.99,-252 51.74,-252 33.41,-230.4 104.66,-230.4 122.99,-252"/>
# <text xml:space="preserve" text-anchor="middle" x="78.2" y="-236.92" font-family="Times,serif" font-size="12.00" fill="White">text</text>
# </g>
# <!-- text&#45;&gt;critique -->
# <g id="edge4" class="edge">
# <title>text&#45;&gt;critique</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M98.6,-230.15C98.6,-201.32 98.6,-126 98.6,-126 98.6,-126 97.42,-126 97.42,-126"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="98.06,-122.5 88.06,-126 98.06,-129.5 98.06,-122.5"/>
# </g>
# <!-- text&#45;&gt;decide -->
# <g id="edge3" class="edge">
# <title>text&#45;&gt;decide</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M59.91,-230.09C59.91,-230.09 59.91,-205.88 59.91,-205.88"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="63.41,-205.88 59.91,-195.88 56.41,-205.88 63.41,-205.88"/>
# </g>
# <!-- text&#45;&gt;finalize -->
# <g id="edge5" class="edge">
# <title>text&#45;&gt;finalize</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M114.15,-241C128.59,-241 141.9,-241 141.9,-241 141.9,-241 141.9,-33.11 141.9,-33.11"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="145.4,-33.11 141.9,-23.11 138.4,-33.11 145.4,-33.11"/>
# </g>
# <!-- text&#45;&gt;revise -->
# <g id="edge2" class="edge">
# <title>text&#45;&gt;revise</title>
# <path fill="none" stroke="DimGrey" stroke-width="0.8" d="M110.79,-236.93C110.79,-236.93 110.79,-90.88 110.79,-90.88"/>
# <polygon fill="DimGrey" stroke="DimGrey" stroke-width="0.8" points="114.29,-90.88 110.79,-80.88 107.29,-90.88 114.29,-90.88"/>
# </g>
# </g>
# </svg>
# </td></tr></tbody></table>
